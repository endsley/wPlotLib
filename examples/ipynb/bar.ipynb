# %%
#!/usr/bin/env python

# %%
import wplotlib
# Out:
# 2021-11-12 13:06:26.118998: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
X = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
Y = [5, 6, 15, 22, 24, 8]
B = wplotlib.bar(X,Y, 'Energy Percentage', 'Energy Type', 'Amount')
